[2004.789213,	231.4359852],
[2004.044646,	161.9278971],
[2002.663701,	129.4098162],
[2002.134803,	78.06547783],
[2001.030709,	88.55518136],
[1950,0]
]

dt = [
    [2019.006378,	495.0587975],
[2017.174488,	142.2735052],
[2015.951575,	49.35681555],
[2009.912126,	27.82531883],
[1950,0]
]

hs = [
    [2018.940945,	199.5804119],
[2018.04874,	169.4363165],
[2016.903071,	229.2828355],
[2015.930315,	203.8315022],
[2014.982835,	202.561696],
[2013.883228,	166.6206592],
[2011.855984,	164.8539723],
[2010.005906,	110.6939767],
[2009.13189,	142.0526694],
[2007.650551,	111.798156],
[2006.25189,	115.6627836],
[2003.349449,	53.71832386],
[1999.988976,	42.34527687],
[1950,0]
]
fs = 15

# %%
# Define the coordinates data in a dictionary
data = {
    "Virtual Reality": vr,
    "System Dynamics": sd,
    "Augmented Reality": ar,
    "Discrete Event Simulation": des,
    "Agent-based Simulation": abs,
    "Digital Twin": dt,
    "Hybrid Simulation": hs
}

# Define the coordinates data in a dictionary
data = {
    "System Dynamics": sd,
    "Augmented Reality": ar,
    "Discrete Event Simulation": des,
    "Agent-based Simulation": abs,
    "Digital Twin": dt,
    "Hybrid Simulation": hs
}

# Define marker styles for each category
marker_styles = {
    "Virtual Reality": 'o',
    "System Dynamics": 's',
    "Augmented Reality": '^',
    "Discrete Event Simulation": 'x',
    "Agent-based Simulation": 'D',
    "Digital Twin": 'v',
    "Hybrid Simulation": 'P',
    # Add more marker styles as needed
}

# Define marker styles for each category
marker_styles = {
    "System Dynamics": 's',
    "Augmented Reality": '^',
    "Discrete Event Simulation": 'x',
    "Agent-based Simulation": 'D',
    "Digital Twin": 'v',
    "Hybrid Simulation": 'P',
    # Add more marker styles as needed
}


# Plot the coordinates for each category
for category, coords in data.items():
    # Sort coordinates based on x-values
    sorted_coords = sorted(coords, key=lambda coord: coord[0])
    # Extract sorted x and y coordinates
    x_coords = [coord[0] for coord in sorted_coords]
    y_coords = [coord[1] for coord in sorted_coords]
    # Plot the coordinates
    plt.plot(x_coords, y_coords, marker=marker_styles[category], markersize=5, label=category, alpha = 0.7)

# Set plot title, labels, and grid
plt.axvline(x=2011, color='black', linestyle='--', label="Industry 4.0 Start")
plt.xlabel('Year', fontsize = fs)
plt.ylabel('Publication Count', fontsize = fs)
#plt.legend(loc='upper left', bbox_to_anchor=(1, 0.75))
plt.legend()
plt.show()

# %%
keyword = {
    "Manufacturing": 66.3,
    "Cyber-physical Systems": 51.3,
    "Agent-based Simulation": 37.5,
    "Decision Making": 26.3,
    "Smart Manufacturing": 21.3,
    "Digital Twin": 18.8,
    "Virtual Reality": 17.5,
    "Internet of Things": 13.8,
    "Discrete Event Simulation": 11.3,
    "Big Data": 10.0
}


# Sort the dictionary by values in descending order
sorted_keyword = dict(sorted(keyword.items(), key=lambda item: item[1], reverse=True))

# Extracting keys and values
keywords = list(sorted_keyword.keys())
values = list(sorted_keyword.values())

# Creating histogram
bars = plt.bar(keywords, values)

# Changing the color of the bar for "DT" to red
bars[keywords.index("Digital Twin")].set_color('red')

# Adding labels and title
plt.ylabel('Frequency (%)', fontsize = fs)
plt.title('Top 10 Keywords in Industry 4.0 Publications', fontsize = fs)

# Set xticks positions and labels
plt.xticks(range(len(keywords)), keywords, rotation=45, ha='right')

# Displaying the histogram
plt.show()
