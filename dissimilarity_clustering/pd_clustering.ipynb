# %%
import pickle
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.cluster.hierarchy import fcluster
from scipy.spatial.distance import euclidean
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from scipy.spatial.distance import cdist
import umap.umap_ as umap
import matplotlib.colors as mcolors

# %%
sp_labels = {0: "Diamond, 3000K",
             1: "Graphite, 3000K",
             2: "0.5 gcc, 1000K",
             3: "1.0 gcc, 2000K",
             4: "2.0 gcc, 6000K",
             5: "3.6 gcc, 6000K",
             6: "3.0 gcc, 8000K",
             7: "Diamond, 300K",
             8: "Graphite, 300K",
             9: "Graphite, 1500K",
             10: "2.0 gcc, 7000K",
             11: "2.5 gcc, 6000K"}

# Function to replace labels in the linkage matrix
def replace_labels(label, label_dict):
    return label_dict[int(label)]

# %% [markdown]
# 2B Analysis

# %%
with open("2b_avg_pd_equilibrium", 'rb') as pickle_file:
    avg_pd = pickle.load(pickle_file)

# Confirmation of appropriate loading
print(np.shape(avg_pd))

# Reshape the array to (12, 60) before creating the DataFrame
reshaped_data = np.array(avg_pd).reshape(12, 60)

# Create a DataFrame
df_2b = pd.DataFrame(reshaped_data)

# Hierarchical clustering
linkage_matrix = linkage(df_2b, method='median')  # You can choose a different linkage method

# Plot the dendrogram with labeled points
plt.figure(figsize=(10, 6))
dendrogram(linkage_matrix, labels=df_2b.index, orientation='top', distance_sort='descending', leaf_label_func=lambda x: replace_labels(x, sp_labels))
plt.title('Dendrogram: 2B P(d) Avgs.')
plt.xticks(rotation='vertical')
plt.ylabel('Distance')
plt.show()

# with open("2b_all_pd_equilibrium", 'rb') as pickle_file:
#     all_pd = pickle.load(pickle_file)

# print(np.shape(all_pd))

# stacked_data = np.vstack(all_pd)
# print(np.shape(stacked_data))

# # Create a DataFrame
# all_df = pd.DataFrame(stacked_data)

# # Hierarchical clustering
# linkage_matrix = linkage(all_df, method='median')  # You can choose a different linkage method

# # Plot the dendrogram with labeled points
# plt.figure(figsize=(10, 6))
# dendrogram(linkage_matrix, labels=all_df.index, orientation='top', distance_sort='descending')
# plt.title('Dendrogram: 2B P(d)')
# plt.xticks(rotation='vertical')
# plt.ylabel('Distance')
# plt.show()
# Out:
# (12, 60, 1)

# %% [markdown]
# 3B Analysis

# %%
with open("3b_avg_pd_equilibrium", 'rb') as pickle_file:
    avg_pd = pickle.load(pickle_file)

# Confirmation of appropriate loading
print(np.shape(avg_pd))

# Reshape the array to (12, 60) before creating the DataFrame
reshaped_data = np.array(avg_pd).reshape(12, 60)

# Create a DataFrame
df_3b = pd.DataFrame(reshaped_data)

# Hierarchical clustering
linkage_matrix = linkage(df_3b, method='median')  # You can choose a different linkage method

# Plot the dendrogram with labeled points
plt.figure(figsize=(10, 6))
dendrogram(linkage_matrix, labels=df_3b.index, orientation='top', distance_sort='descending', leaf_label_func=lambda x: replace_labels(x, sp_labels))
plt.title('Dendrogram: 3B P(d) Avgs.')
plt.xticks(rotation='vertical')
plt.ylabel('Distance')
plt.show()

# with open("3b_all_pd_equilibrium", 'rb') as pickle_file:
#     all_pd = pickle.load(pickle_file)

# print(np.shape(all_pd))

# stacked_data = np.vstack(all_pd)
# print(np.shape(stacked_data))

# # Create a DataFrame
# all_df = pd.DataFrame(stacked_data)

# # Hierarchical clustering
# linkage_matrix = linkage(all_df, method='median')  # You can choose a different linkage method

# # Plot the dendrogram with labeled points
# plt.figure(figsize=(10, 6))
# dendrogram(linkage_matrix, labels=all_df.index, orientation='top', distance_sort='descending')
# plt.title('Dendrogram: 3B P(d)')
# plt.xticks(rotation='vertical')
# plt.ylabel('Distance')
# plt.show()
# Out:
# (12, 60, 1)

# %% [markdown]
# 4B Analysis

# %%
with open("4b_avg_pd_equilibrium", 'rb') as pickle_file:
    avg_pd = pickle.load(pickle_file)

# Confirmation of appropriate loading
print(np.shape(avg_pd))

# Reshape the array to (12, 60) before creating the DataFrame
reshaped_data = np.array(avg_pd).reshape(12, 60)

# Create a DataFrame
df_4b = pd.DataFrame(reshaped_data)

# Hierarchical clustering
linkage_matrix = linkage(df_4b, method='median')  # You can choose a different linkage method

# Plot the dendrogram with labeled points
plt.figure(figsize=(10, 6))
dendrogram(linkage_matrix, labels=df_4b.index, orientation='top', distance_sort='descending', leaf_label_func=lambda x: replace_labels(x, sp_labels))
plt.title('Dendrogram: 4B P(d) Avgs.')
plt.xticks(rotation='vertical')
plt.ylabel('Distance')
plt.show()

# with open("4b_all_pd_equilibrium", 'rb') as pickle_file:
#     all_pd = pickle.load(pickle_file)

# print(np.shape(all_pd))

# stacked_data = np.vstack(all_pd)
# print(np.shape(stacked_data))

# # Create a DataFrame
# all_df = pd.DataFrame(stacked_data)

# # Hierarchical clustering
# linkage_matrix = linkage(all_df, method='median')  # You can choose a different linkage method

# # Plot the dendrogram with labeled points
# plt.figure(figsize=(10, 6))
# dendrogram(linkage_matrix, labels=all_df.index, orientation='top', distance_sort='descending')
# plt.title('Dendrogram: 4B P(d) Avgs.')
# plt.xticks(rotation='vertical')
# plt.ylabel('Distance')
# plt.show()
# Out:
# (12, 60, 1)

# %%
import numpy as np
from scipy.cluster.hierarchy import fcluster
from scipy.spatial.distance import euclidean
from sklearn.metrics import accuracy_score
 
with open("2b_avg_pd_equilibrium", 'rb') as pickle_file:
    avg_pd_2b = pickle.load(pickle_file)
 
with open("3b_avg_pd_equilibrium", 'rb') as pickle_file:
    avg_pd_3b = pickle.load(pickle_file)
 
print(np.shape(avg_pd_2b))
 
# Combine the arrays along the second axis (axis=1)
combined_array = np.concatenate((avg_pd_2b, avg_pd_3b), axis=1)
 
# Verify the shape of the combined array
print(combined_array.shape)  # Output will be (12, 180, 1)
 
# Reshape the array to (12, 60) before creating the DataFrame
reshaped_data = np.array(combined_array).reshape(12, 120)
 
# Create a DataFrame
df_2b3b = pd.DataFrame(reshaped_data)
 
# Hierarchical clustering
linkage_matrix = linkage(df_2b3b , method='median')  # You can choose a different linkage method
 
# Plot the dendrogram with labeled points
plt.figure(figsize=(10, 6))
dendrogram(linkage_matrix, labels=df_2b3b.index, orientation='top', distance_sort='descending', leaf_label_func=lambda x: replace_labels(x, sp_labels))
plt.title('Dendrogram: 2B+3B P(d) Avgs.')
plt.xticks(rotation='vertical')
plt.ylabel('Distance')
plt.show()
 
# Step 1: Choose a threshold distance to form clusters
threshold_distance = 0.005  # Adjust this based on your data and clustering objectives
# Step 2: Compute cluster labels using the threshold distance
cluster_labels = fcluster(linkage_matrix, threshold_distance, criterion='distance')
print(cluster_labels) # Confirm there are 12 unique clusters
# Out:
# (12, 60, 1)
# (12, 120, 1)
# [ 1  3 11  9  5  6  8  2 10  4  5  7]

# %% [markdown]
# All Body Analysis

# %%
with open("2b_avg_pd_equilibrium", 'rb') as pickle_file:
    avg_pd_2b = pickle.load(pickle_file)

with open("3b_avg_pd_equilibrium", 'rb') as pickle_file:
    avg_pd_3b = pickle.load(pickle_file)

with open("4b_avg_pd_equilibrium", 'rb') as pickle_file:
    avg_pd_4b = pickle.load(pickle_file)

print(np.shape(avg_pd_2b))

# Combine the arrays along the second axis (axis=1)
combined_array = np.concatenate((avg_pd_2b, avg_pd_3b, avg_pd_4b), axis=1)

# Verify the shape of the combined array
print(combined_array.shape)  # Output will be (12, 180, 1)

# Reshape the array to (12, 60) before creating the DataFrame
reshaped_data = np.array(combined_array).reshape(12, 180)

# Create a DataFrame
avg_df = pd.DataFrame(reshaped_data)
print(np.shape(avg_df))

# Hierarchical clustering
linkage_matrix = linkage(avg_df, method='median')  # You can choose a different linkage method

# Plot the dendrogram with labeled points
plt.figure(figsize=(10, 6))
dendrogram(linkage_matrix, labels=avg_df.index, orientation='top', distance_sort='descending', leaf_label_func=lambda x: replace_labels(x, sp_labels))
plt.title('Dendrogram: All P(d) Avgs.')
plt.xticks(rotation='vertical')
plt.ylabel('Distance')
plt.show()

# Step 1: Choose a threshold distance to form clusters
threshold_distance = 0.005  # Adjust this based on your data and clustering objectives
# Step 2: Compute cluster labels using the threshold distance
cluster_labels = fcluster(linkage_matrix, threshold_distance, criterion='distance')
print(cluster_labels) # Confirm there are 12 unique clusters
# Out:
# (12, 60, 1)
# (12, 180, 1)
# (12, 180)
# [ 1  8 12 10  3  5  7  2 11  9  4  6]

# %%
sp_labels = {0: "Diamond, 3000K",
             1: "Graphite, 3000K",
             2: "0.5 gcc, 1000K",
             3: "1.0 gcc, 2000K",
             4: "2.0 gcc, 6000K",
             5: "3.6 gcc, 6000K",
             6: "3.0 gcc, 8000K",
             7: "Diamond, 300K",
             8: "Graphite, 300K",
             9: "Graphite, 1500K",
             10: "2.0 gcc, 7000K",
             11: "2.5 gcc, 6000K"}

shape_map = [".","v","^","1","s","p","P","*","x","d","+","H"]    # Add more shapes if needed

# Assuming avg_pd is a DataFrame containing the curves
for i in range(len(avg_df)):
    y_values = avg_df.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, label=sp_labels.get(i, f'Curve {i}'))

plt.xlabel('d')
plt.ylabel('P(d)')
plt.title('All P(d) Curves (2+3+4B)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

solids = [0, 1, 7, 8, 9]
graphites = [1, 8, 9]
ld_liquids = [2, 3]
hd_liquids = [4, 5, 6, 10, 11]
diamonds = [0, 7]
liquids = [2, 3, 4, 5, 6, 10, 11]

for i in solids:
    y_values = avg_df.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha=0.5, color='r', label=sp_labels.get(i, f'Curve {i}'))
for i in liquids:
    y_values = avg_df.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='b', label=sp_labels.get(i, f'Curve {i}'))
plt.xlabel('d')
plt.ylabel('P(d)')
plt.title('Solids vs. Liquids (2+3+4B)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

for i in graphites:
    y_values = avg_df.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='r', label=sp_labels.get(i, f'Curve {i}'))
for i in ld_liquids:
    y_values = avg_df.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='b', label=sp_labels.get(i, f'Curve {i}'))
for i in hd_liquids:
    y_values = avg_df.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='g', label=sp_labels.get(i, f'Curve {i}'))
for i in diamonds:
    y_values = avg_df.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='y', label=sp_labels.get(i, f'Curve {i}'))

plt.xlabel('d')
plt.ylabel('P(d)')
plt.title('Graphites, LD Liquids, HD Liquids, Diamonds (2+3+4B)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
df_2b

# Assuming avg_pd is a DataFrame containing the curves
for i in range(len(df_2b)):
    y_values = df_2b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, label=sp_labels.get(i, f'Curve {i}'))

plt.xlabel('d')
plt.ylabel('P(d)')
plt.title('All P(d) Curves (2B)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

solids = [0, 1, 7, 8, 9]
graphites = [1, 8, 9]
ld_liquids = [2, 3]
hd_liquids = [4, 5, 6, 10, 11]
diamonds = [0, 7]
liquids = [2, 3, 4, 5, 6, 10, 11]

for i in solids:
    y_values = df_2b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha=0.5, color='r', label=sp_labels.get(i, f'Curve {i}'))
for i in liquids:
    y_values = df_2b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='b', label=sp_labels.get(i, f'Curve {i}'))
plt.xlabel('d')
plt.ylabel('P(d)')
plt.title('Solids vs. Liquids (2B)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

for i in graphites:
    y_values = df_2b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='r', label=sp_labels.get(i, f'Curve {i}'))
for i in ld_liquids:
    y_values = df_2b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='b', label=sp_labels.get(i, f'Curve {i}'))
for i in hd_liquids:
    y_values = df_2b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='g', label=sp_labels.get(i, f'Curve {i}'))
for i in diamonds:
    y_values = df_2b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='y', label=sp_labels.get(i, f'Curve {i}'))

plt.xlabel('d')
plt.ylabel('P(d)')
plt.title('Graphites, LD Liquids, HD Liquids, Diamonds (2B)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
df_3b

# Assuming avg_pd is a DataFrame containing the curves
for i in range(len(df_3b)):
    y_values = df_3b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, label=sp_labels.get(i, f'Curve {i}'))

plt.xlabel('d')
plt.ylabel('P(d)')
plt.title('All P(d) Curves (3B)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

solids = [0, 1, 7, 8, 9]
graphites = [1, 8, 9]
ld_liquids = [2, 3]
hd_liquids = [4, 5, 6, 10, 11]
diamonds = [0, 7]
liquids = [2, 3, 4, 5, 6, 10, 11]

for i in solids:
    y_values = df_3b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha=0.5, color='r', label=sp_labels.get(i, f'Curve {i}'))
for i in liquids:
    y_values = df_3b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='b', label=sp_labels.get(i, f'Curve {i}'))
plt.xlabel('d')
plt.ylabel('P(d)')
plt.title('Solids vs. Liquids (3B)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

for i in graphites:
    y_values = df_3b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='r', label=sp_labels.get(i, f'Curve {i}'))
for i in ld_liquids:
    y_values = df_3b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='b', label=sp_labels.get(i, f'Curve {i}'))
for i in hd_liquids:
    y_values = df_3b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='g', label=sp_labels.get(i, f'Curve {i}'))
for i in diamonds:
    y_values = df_3b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='y', label=sp_labels.get(i, f'Curve {i}'))

plt.xlabel('d')
plt.ylabel('P(d)')
plt.title('Graphites, LD Liquids, HD Liquids, Diamonds (3B)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
df_4b

# Assuming avg_pd is a DataFrame containing the curves
for i in range(len(df_4b)):
    y_values = df_4b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, label=sp_labels.get(i, f'Curve {i}'))

plt.xlabel('d')
plt.ylabel('P(d)')
plt.title('All P(d) Curves (4B)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

solids = [0, 1, 7, 8, 9]
graphites = [1, 8, 9]
ld_liquids = [2, 3]
hd_liquids = [4, 5, 6, 10, 11]
diamonds = [0, 7]
liquids = [2, 3, 4, 5, 6, 10, 11]

for i in solids:
    y_values = df_4b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha=0.5, color='r', label=sp_labels.get(i, f'Curve {i}'))
for i in liquids:
    y_values = df_4b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='b', label=sp_labels.get(i, f'Curve {i}'))
plt.xlabel('d')
plt.ylabel('P(d)')
plt.title('Solids vs. Liquids (4B)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

for i in graphites:
    y_values = df_4b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='r', label=sp_labels.get(i, f'Curve {i}'))
for i in ld_liquids:
    y_values = df_4b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='b', label=sp_labels.get(i, f'Curve {i}'))
for i in hd_liquids:
    y_values = df_4b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='g', label=sp_labels.get(i, f'Curve {i}'))
for i in diamonds:
    y_values = df_4b.iloc[i]
    x_values = range(len(y_values))
    plt.plot(x_values, y_values, marker=shape_map[i], linestyle='-', alpha = 0.5, color='y', label=sp_labels.get(i, f'Curve {i}'))

plt.xlabel('d')
plt.ylabel('P(d)')
plt.title('Graphites, LD Liquids, HD Liquids, Diamonds (4B)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
